# %%
import numpy as np
import pandas as pd

from scipy.stats import mode

# %%
DATASETH_PATH = "/content/drive/MyDrive/Colab Notebooks/data/housing.csv"
PREPARED_DATASETH_PATH = "/content/drive/MyDrive/Colab Notebooks/data/housing_prepared.csv"

# %% [markdown]
# ## Загрузка данных

# %%
housing_df = pd.read_csv(DATASETH_PATH, sep=",")
housing_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    id
# 0   0
# 1   1
# 2   2
# 3   3
# 4   4

# %%
# Вывод последних значений
housing_df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637         NaN       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity     id
# 20635          INLAND  20635
# 20636          INLAND  20636
# ...

# %%
# Вывод случайных 10 объектов из датафрейма
housing_df.sample(10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1369     -122.13     38.00                33.0       2821.0           652.0
# 16130    -122.48     37.78                48.0       2835.0           728.0
# 10921    -117.90     33.73                32.0       2930.0           833.0
# 7861     -118.14     33.90                39.0       1379.0           282.0
# 20299    -119.21     34.18                13.0       6103.0          1319.0
# 9409     -122.53     37.89                35.0       4127.0           689.0
# 13262    -117.65     34.10                19.0       1688.0           365.0
# 8492     -118.30     33.90                27.0       3267.0           762.0
# 8070     -118.18     33.84                43.0       2561.0           544.0
# 8291     -118.15     33.76                36.0       2916.0           785.0
#
#        population  households  median_income  median_house_value  \
# 1369       1206.0       640.0         2.5481            150800.0
# ...

# %%
# Вывод доли случайных объектов из датафрейма
housing_df.sample(frac=.75)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15319    -117.35     33.20                23.0       3297.0           728.0
# 14442    -117.25     32.80                35.0       2281.0           506.0
# 75       -122.28     37.81                17.0       1237.0           462.0
# 20240    -119.25     34.27                46.0        679.0           159.0
# 9933     -122.30     38.28                31.0       1633.0           316.0
# ...          ...       ...                 ...          ...             ...
# 9196     -119.45     37.21                17.0       3538.0           726.0
# 19131    -122.73     38.26                35.0       3941.0           645.0
# 9492     -123.20     39.23                26.0        786.0           168.0
# 16796    -122.43     37.66                29.0       3541.0           786.0
# 11326    -117.96     33.75                14.0       2509.0           611.0
#
# ...

# %%
# Размерность датафрейма строки / столбцы
housing_df.shape
# Out:
# (20640, 11)

# %%
# Доступ к столбцам
housing_df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity', 'id'],
#       dtype='object')

# %%
# Доступ к индексам
housing_df.index
# Out:
# RangeIndex(start=0, stop=20640, step=1)

# %% [markdown]
# Получение одного или нескольких признаков из датасета

# %%
housing_df.total_rooms.head()
# Out:
# 0     880.0
# 1    7099.0
# 2    1467.0
# 3    1274.0
# 4    1627.0
# Name: total_rooms, dtype: float64

# %%
housing_df[["total_rooms", "population"]].head()
# Out:
#    total_rooms  population
# 0        880.0       322.0
# 1       7099.0      2401.0
# 2       1467.0       496.0
# 3       1274.0       558.0
# 4       1627.0       565.0

# %% [markdown]
# ## Фильтрация

# %%
# Фильтрация с помощью булевых масок
mask = housing_df["housing_median_age"] < 5

# %%
housing_df[mask].head()
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 59     -122.29     37.82                 2.0        158.0            43.0
# 854    -122.01     37.59                 2.0        838.0           295.0
# 871    -122.07     37.52                 3.0      14014.0          2861.0
# 882    -121.96     37.55                 4.0       3746.0           993.0
# 946    -121.92     37.72                 4.0       7477.0          1576.0
#
#      population  households  median_income  median_house_value  \
# 59         94.0        57.0         2.5625             60000.0
# 854       240.0       149.0         2.8750            237500.0
# 871      7205.0      2753.0         6.0824            273500.0
# 882      1606.0       838.0         4.1387            162500.0
# 946      2937.0      1506.0         5.1437            299400.0
#
#     ocean_proximity   id
# 59         NEAR BAY   59
# 854        NEAR BAY  854
# 871        NEAR BAY  871
# 882       <1H OCEAN  882
# ...

# %%
mask = (housing_df["housing_median_age"] < 5) & (housing_df["population"] < 100)

# %%
housing_df[mask].head()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 59      -122.29     37.82                 2.0        158.0            43.0
# 1566    -121.96     37.74                 2.0        200.0            20.0
# 2774    -115.80     33.26                 2.0         96.0            18.0
# 3125    -117.76     35.22                 4.0         18.0             3.0
# 3126    -117.79     35.21                 4.0          2.0             2.0
#
#       population  households  median_income  median_house_value  \
# 59          94.0        57.0         2.5625             60000.0
# 1566        25.0         9.0        15.0001            350000.0
# 2774        30.0        16.0         5.3374             47500.0
# 3125         8.0         6.0         1.6250            275000.0
# 3126         6.0         2.0         2.3750            137500.0
#
#      ocean_proximity    id
# 59          NEAR BAY    59
# 1566       <1H OCEAN  1566
# 2774          INLAND  2774
# ...

# %%
# Инверсия маски через оператор ~
housing_df[~mask].head() # при использовании ~, строгие операции > / < становаться >= / <=
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    id
# 0   0
# 1   1
# 2   2
# 3   3
# 4   4

# %% [markdown]
# ## Индексация
